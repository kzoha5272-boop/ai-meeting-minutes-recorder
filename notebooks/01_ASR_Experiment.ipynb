# %%
# !pip install -q faster-whisper
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.8/35.8 MB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.6/39.6 MB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 62.6 MB/s eta 0:00:00

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("Running on CPU")
# Out:
# PyTorch version: 2.11.0+cpu
# CUDA available: False
# Running on CPU

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-03ec3fdd-9432-4687-bd19-125d051001b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03ec3fdd-9432-4687-bd19-125d051001b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from faster_whisper import WhisperModel

model = WhisperModel(
    "base.en",
    device="cuda" if torch.cuda.is_available() else "cpu",
    compute_type="float16" if torch.cuda.is_available() else "int8"
)

print("Whisper model loaded successfully.")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Whisper model loaded successfully.

# %%
import time

audio_file = "WhatsApp Ptt 2026-09-22 at 11.13.43 PM.ogg"

start_time = time.time()

segments, info = model.transcribe(
    audio_file,
    beam_size=5
)

segments = list(segments)

processing_time = time.time() - start_time

print("Detected language:", info.language)
print("Language probability:", info.language_probability)
print("Processing time:", round(processing_time, 2), "seconds")
# Out:
# Detected language: en
# Language probability: 1
# Processing time: 2.84 seconds

# %%
for segment in segments:
    print(
        f"[{segment.start:.2f}s -> {segment.end:.2f}s] "
        f"{segment.text}"
    )
# Out:
# [0.00s -> 8.44s]  Hello, how are you? This is Joach and I hope you all know me. Hello, hello, hello.

# %%
transcript_text = "\n".join(
    f"[{segment.start:.2f}s -> {segment.end:.2f}s] {segment.text}"
    for segment in segments
)

with open("transcript.txt", "w", encoding="utf-8") as f:
    f.write(transcript_text)

print("Transcript saved successfully.")
# Out:
# Transcript saved successfully.

# %%
from faster_whisper import WhisperModel
import time
import torch

small_model = WhisperModel(
    "small.en",
    device="cpu",
    compute_type="int8"
)

print("small.en model loaded successfully.")
# Out:
# small.en model loaded successfully.

# %%
start_time = time.time()

small_segments, small_info = small_model.transcribe(
    audio_file,
    beam_size=5
)

small_segments = list(small_segments)

small_processing_time = time.time() - start_time

print("Detected language:", small_info.language)
print("Language probability:", small_info.language_probability)
print("Processing time:", round(small_processing_time, 2), "seconds")
# Out:
# Detected language: en
# Language probability: 1
# Processing time: 13.08 seconds

# %%
for segment in small_segments:
    print(
        f"[{segment.start:.2f}s -> {segment.end:.2f}s] "
        f"{segment.text}"
    )
# Out:
# [0.00s -> 8.48s]  Hello, how are you? This is your icon. Hope you all know me. Hello, hello, hello.

# %%
results = [
    {
        "model": "faster-whisper base.en",
        "device": "CPU",
        "processing_time_sec": 2.84,
        "language": "English",
        "language_probability": 1.0,
        "transcript": "Hello, how are you? This is Joach and I hope you all know me. Hello, hello, hello."
    },
    {
        "model": "faster-whisper small.en",
        "device": "CPU",
        "processing_time_sec": 13.08,
        "language": "English",
        "language_probability": 1.0,
        "transcript": "Hello, how are you? This is your icon. Hope you all know me. Hello, hello, hello."
    }
]

import pandas as pd

pd.DataFrame(results)
# Out:
#                      model device  processing_time_sec language  \
# 0   faster-whisper base.en    CPU                 2.84  English
# 1  faster-whisper small.en    CPU                13.08  English
#
#    language_probability                                         transcript
# 0                   1.0  Hello, how are you? This is Joach and I hope y...
# 1                   1.0  Hello, how are you? This is your icon. Hope yo...
